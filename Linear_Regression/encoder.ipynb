# %%
# write a code for target encoder
import numpy as np
import pandas as pd
from sklearn.preprocessing import TargetEncoder
n_rows = 1000
data = {
    'color':np.random.choice(['red', 'blue','green'], n_rows),
    'size':np.random.choice(['small', 'medium', 'large'], n_rows),
    'material':np.random.choice(['plastic','metal','wood'], n_rows),  
    'prices':np.random.randint(1, 500, n_rows)
}

df = pd.DataFrame(data)

# %%
from sklearn.preprocessing import category_encoders, LabelEncoder, OneHotEncoder, OrdinalEncoder
from category_encoder import TargetEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X=df.drop(columns='price')

y=df.price
xtrain,xtest,ytrain,ytest = train_test_split(X,y,train_size=0.8, rando)

# %%
label_encoder = LabelEncoder()
updated_xtrain = label_encoder.fit_transform(xtrain['color'])
'''valueeroor'''

# %%
label_encoder.fit_transform(xtrain['color'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 label_encoder.fit_transform(xtrain['color'])
#
# NameError: name 'label_encoder' is not defined
